# %% [markdown]
# # Lernpfad Python Grundlagen
#
# ## Voraussetzungen
#
# ### Technik
#
# * Python ist installiert

# %%
# !python -V
# Out:
# Python 3.12.1

# %% [markdown]
# * Visual Studio Code mit Python und Python Debugger Extension von Microsoft sind installiert
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Teilnehmende
#
# * Elementare Kenntnisse der IT: Was sind Daten, was ist Datenverarbeitung?
# * Grundlagen des Internets, sicherer Umgang mit dem Browser
# * Arbeiten mit CMD/Powershell/Bash
# * Grundlagen der Programmierung sind hilfreich

# %% [markdown]
# ### Inhalt und Lernpfad
#
# * Insgesamt 5 Tage mit 6h Zeitaufwand pro Tag
# * Pro Tag 4 Blöcke mit jeweils 90 Minuten, insgesamt also 30 Blöcke
# * Als Ressource wird das Cegos-Handout verteilt. Dies muss aber nicht sklavisch 1:1 besprochen werden; es dient als weiterer Leitfaden. Die Inhalte werden zu 90% im realen Quellcode abgelegt. Welche Programme erstellt werden kann jeder Referent / jede Referentin nach jeweiliger Vorliebe pro Duchführung entscheiden.
#   * Hinweise
#     * Als Leitfaden können die Beispiele auf https://github.com/Javacream/org.javacream.training.python/tree/LearningHub genommen werden
#     * Fragen und Anregungen an rainer.sawitzki@gmail.com

# %% [markdown]
# #### Block 1: Einführung
#
# * Vorstellung des Referenten
# * Vorstellung des Lernpfades, wo starten wir, wo geht die Reise hin?
# * Teilnehmer-Vorstellung mit Abfrage der Vorkenntnisse sowie der individuellen Zielsetzung
# * Check: Ist die Umgebung korrekt eingerichtet?
#   * Hierzu VSC starten, eine simple Date first.py anlegen und über VSC starten

# %%
# first.py

print('Hello Python')
# Out:
# Hello Python

# %% [markdown]
# * Vorstellung von Online-Ressourcen
#   * Python Dokumentation mit dem Hinweis "Vollständig, aber sehr technisch detailliert und damit aktuell unbrauchbar"
#   * W3School
#   * Eigene Vorlieben des Referenten

# %% [markdown]
# #### Block 2: Variablen
#
# * Lernziel:
#   * Deklaration und Nutzen von Variablen
#   * Strings und Zahlen
#   * Formatted Strings `f'...'`
# * Hinweise
#   * Dass hier noch keine relevante Programmlogik implementiert werden kann ist selbstverständlich
#   * Die Buildin-Funktionen `print`und `input` können benutzt werden
# * Übung: So etwas wie Einlesen - Zuweisen - Ausgeben
# * Notwendige Ergänzung: VSC-Debugger einführen, Haltepunkte, Oberfläche, Betrachten und Ändern von Werten während des Debbuggings

# %% [markdown]
# #### Block 3: Datentypen und Operatoren
# * Lernziele:
#   * Einführen der Literale für Zeichenketten, Ganz- und Fließkommazahlen
#   * Einführen der mathematische Operatoren sowie `+` und `*` für Zahlen und Zeichenketten
#   * Umwandlung mit `str` sowie `int`und `float`
# * Übung:
#   * Berechnen des BMI, dazu Eingabe eines Namens, Gewicht und Größe

# %% [markdown]
# #### Block 4: Kontrollstrukturen
#
# * Lernziele:
#   * Boolean und Boolean Algebra
#   * `while`, `if-else` und `try-except`
# * Hinweise
#   * for-Schleifen werden erst mit den Datencontainern behandelt!
#   * Es geht hier um das Fangen von Exceptions, kein `raise`
# * Übung
#   * Erweiterung des BMI-Beispiels um die Ausgaben untergewichtig, normal, übergewichtig, adipös
#   * Abfangen der Fehler bei der Konvertierung der Gewicht-/Größeneingabe
#   * Programmwiederholung bis Eingabe 'exit'

# %% [markdown]
# #### Block 5: Datencontainer
#
# * Lernziele:
#   * Einführen der Datencontainer List, Set, Dict, Tuple, Range
#   * foreach-Schleife
# * Übung
#   * Literale für Datencontainer sowie Nutzen der korrespondierenden Buildin-Funktionen
#   * Iteration mit foreach

# %% [markdown]
# #### Block 6: Gruppen- oder Einzelarbeit mit einem komplexeren Beispiel
#
# * Ideen: Adressbuch, Postleitzahlen mit jeweils Programmen für
#     * Gib mir die Adresse (:str) einer Person (:str)
#     * Gib mir die Liste der Postleitzahlen einer Stadt
# * Hinweis
#   * Die Daten sind natürlich noch nicht aus einer Datei zu lesen, sondern nur einige wenige werden im Skript definiert

# %% [markdown]
# #### Block 7: Funktionen
#
# * Lernziele
#   * Definition von Funktionen: Name, Parameter, Rückgabewert
#   * Aufruf von Funktionen
# * Übung
#   * Umgestaltung der Beispiel aus dem Workshop und damit bessere Strukturierung des bisherigen Spaghetti-Codes

# %% [markdown]
# #### Block 8: Details zu Funktionen
#
# * Dieser Block dient als Füller und kann, falls die Teilnehmenden zu stark gefordert sind statt der Lernziele für Wiederholungen genutzt werden
# * Lernziele
#   * Überladen von Funktionen in Python -> Nein, Funktionen werden überschrieben
#   * Default-Werte von Parametern
#   * `args` und `kwargs`
# * Übungen nach Bedarf

# %% [markdown]
# #### Block 9: Die OOP-Syntax
#
# * Lernziele
#   * Punkt-Operator
#   * Methoden als Funktionen, die einem Objekt zugeordnet sind
#   * Referenzen auf Objekte
#   * Referenzen als Parameter
#     * Was passiert, wenn innerhalb einer Funktion dem Parameter ein neuer Wert zugewiesen wird bzw. z.B. eine Liste verändert wird?
#     * Hier ist der Debugger extrem nützlich!
# * Hinweis
#   * Ein Stack-Heap-Diagramm des Python-Interpreters kann hier sehr nützlich sein
#     * Die Teilnehmenden sollen dann auch solche Diagramme zeigen und mit dem Live-Debugging zusammenbringen
#   * ![image.png](attachment:image.png)

# %% [markdown]
# #### Block 10: Eigene Klassen
#
# * Lernziele
#   * Erstellen einer simplen Datenstruktur `Person`
#     * Hinweis: Nutzen Sie ein Klassendiagramm zur Modellierung
#   * Erweitern des Klassendiagramms um eine unidirektionale Assoziation: 'Eine Person hat eine Adresse'
#   * Kurze Einfürung der Vererbung, 'Ein Student ist eine Person und kann an einer Universität studieren'
# * Hinweis
#   * Mehrfachvererbung und Mixins können angesprochen werden, sind aber nicht zwingend zu vertiefen
#   * Überladen von Methoden ansprechen, Konstruktoren überladen, `super()` benutzen

# %% [markdown]
# #### Block 11: Gruppen- oder Einzelarbeit mit einem komplexeren Beispiel
#
# * Idee
#   * Bücher (isbn, title, price, pages) werden von Verlegern (id, name) verlegt und sind von Autoren (id, lastname, firstname) geschrieben
#   * Die Verwaltung der Daten wird von einem PublishingService übernommen. Dieser hat Methoden zum Anlegen von Books, Publishers und Authors sowie zum Aufbau der Relationen
#     * Hier ist wichtig darauf zu achten, dass die Beziehungen konsistent aufgebaut werden: So darf es nicht passieren, dass ein Buch einen Verleger referenziert, der das Buch nicht in seiner Bücherliste enthält

# %% [markdown]
# #### Block 12: Dunder-Methoden
#
# * Wieder ein Füller, der alternativ zur Wiederholung genutzt werden kann
# * Lernziele
#   * Kapselung in Python durch Dunder-Methoden `__xyz__`
#   * Beispiel `__repr__`, `__eq__`, `__hash__`

# %% [markdown]
# #### Block 13: Collections Revisited
#
# * Hinweis
#   * Nach den ersten drei Tagen sind die Python-Core-Grundlagen geschaffen. Nun wird es praktischer, neue FEatures werden nur noch nebenbei eingeführt
# * Lernziele
#   * List-Comprehensions zum Filtern und transformieren von Daten
#   * Lambda-Funktionen z.B. zum Sortieren einer Liste
# * Übung
#     * Der PublishingService der letzten Übung wird um Such-Funktionen erweitert
#       * Ideen
#         * Gib mir alle teuren Bücher
#         * Gib mir alle Autoren, die für einen bestimmten Verleger schreiben
#         * ...

# %% [markdown]
# #### Block 14: Dateioperationen
#
# * Lernziele
#   * Lesen und Schreiben von Text-Dateien
#   * Fehlerbehandlung
#   * Ressourcenverwaltung, `with`-Statement
# * Übung
#   * Der Datenbestand des vorherigen Beispiels wird aus einer Text-Datei gelesen
# * Hinweis
#     * pickle, json etc spielt noch keine Rolle

# %% [markdown]
# #### Block 15: Module
#
# * Lernziel
#     * Was sind die Module?
#     * Welche Module sind im Standard-Python enthalten?
#     * Die Module os, datetime, csv, json
#     * Testen mit unittest
# * Übung
#     * Erweitern des Buches um ein Erscheinungsdatum
#     * Einlesen und Wegschreiben der Daten im JSON-Format
#     * Konzipieren und Schreiben von Unittests

# %% [markdown]
# Block 16: pip und PyPi
#
# * Lernziele
#     * Installieren von Modulen mit pip
#     * Importieren von Modulen
#       * Hinweis: Das ist natürlich nichts anderes als das normale `import`...
# * Übung
#     * Installation des `request`-Modules
#     * Absetzen eines Requests auf einen RESTful-WebService, z.B. [Books Librray](https://openlibrary.org/api/books)
#       * Hinweis
#         * Das Thema REST wird am nächsten Tag noch etwas vertieft, ist hier aber doch ziemlich cool

# %% [markdown]
# #### Block 17: Datenbank-Zugriff
#
# * Voraussetzung
#     * Aufsetzen einer Test-Datenbank z.B. MySQL mit Docker. Das ist alleinige Aufgabe des REferenten, die Teilnehmenden sollen damit nicht konfrontiert werden
#     * Aufsetzen eines Datenbank-Schemas für BOOKS, AUTHORS, PUBLISHERS
# * Lernziele
#   * Knapper SQL-Primer
#   * Installation des mysql-connector-Modules
#   * Absetzen von SQL-Queries
# * Übung
#     * Nutzen einer simplen Messages-Tabelle, die es den Teilnehmenden ermöglicht, Nachrichten zu lesen und zu schreiben

# %% [markdown]
# #### Block 18: Zugriff auf einen RESTful Web Service
#
# * Lernziele
#   * Knappe Einführung in REST / CRUD-Services
#   * requests-Modul zum Absetzen von GET/POST/PUT/DELETE
# * Übung
#   * Lesen eins JSON-Dokuments von einem REST-Service und schreiben einer Nachricht in die relationale Datenbank

# %% [markdown]
# #### Block 19: SSH mit paramiko
#
# * Lernziele
#   * Installation des Paramiko-Moduls
#   * Schreiben einer Anwendung, die via SSH auf einen Linux-Server verbindet und dort einen Shell-Befehl ausführt
#   * Schreiben einer simplen sftp-Anwendung, die eine Datei auf / von einem entfernten Linux-Rechner kopiert

# %% [markdown]
# #### Block 20: Abschluss
#
# * Zusammenfassung: "Wie weit sind wir gekommen"
# * Ausblick auf nicht-angesprochene / weiterführende Themen
# * Teilnehmenden-Feedback
