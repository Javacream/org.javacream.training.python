# %% [markdown]
# # Lernpfad Python Fortgeschrittene
#
# ## Voraussetzungen
#
# ### Technik
#
# * Python ist installiert

# %%
# !python -V
# Out:
# Python 3.12.1

# %% [markdown]
# * Visual Studio Code mit Python und Python Debugger Extension von Microsoft sind installiert
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * Installation von Modulen mit pip ist möglich

# %%
# !pip install requests

# %% [markdown]
# ### Teilnehmende
#
# * Grundlagen des Internets, sicherer Umgang mit dem Browser
# * Arbeiten mit CMD/Powershell/Bash
# * Grundlagen Python Programmierung

# %% [markdown]
# ### Inhalt und Lernpfad
#
# * Insgesamt 3 Tage mit 6h Zeitaufwand pro Tag
# * Pro Tag 4 Blöcke mit jeweils 90 Minuten, insgesamt also 12 Blöcke
# * Als Ressource wird das Cegos-Handout verteilt. Dies muss aber nicht sklavisch 1:1 besprochen werden; es dient als weiterer Leitfaden. Die Inhalte werden zu 90% im realen Quellcode abgelegt. Welche Programme erstellt werden kann jeder Referent / jede Referentin nach jeweiliger Vorliebe pro Duchführung entscheiden.
#   * Hinweise
#     * Als Leitfaden können die Beispiele auf https://github.com/Javacream/org.javacream.training.python/tree/LearningHub_Advanced genommen werden
#     * Fragen und Anregungen an rainer.sawitzki@gmail.com

# %% [markdown]
# #### Block 1: Einführung
#
# * Vorstellung des Referenten
# * Vorstellung des Lernpfades, wo starten wir, wo geht die Reise hin?
# * Teilnehmer-Vorstellung mit Abfrage der Vorkenntnisse sowie der individuellen Zielsetzung
# * Check: Ist die Umgebung korrekt eingerichtet?
#   * Hierzu VSC starten, eine simple Date first.py anlegen und über VSC starten

# %%
# first.py

print('Hello Python')
# Out:
# Hello Python

# %% [markdown]
# * Vorstellung von Online-Ressourcen
#   * [Python Dokumentation](https://docs.python.org/3/)
#   * [W3School](https://www.w3schools.com/python/)
#   * Eigene Vorlieben des Referenten

# %% [markdown]
# #### Block 2: Zusammenfassung der Themen des Grundlagenkurses
#
# * Nivellierung der Kenntnisse der Teilnehmenden:
#   * Collections
#   * Funktionen
#   * Grundlagen der OOP
# * Hinweise
#   * Hierzu können die Beispiele aus dem Grundlagenkurs benutzt werden
#   * Diese befinden sich im Verzeichnis src_basic

# %% [markdown]
# ### Block 3: Typisierung revisited
# * Lernziele
#   * Python ist und bleibt eine statisch untypisierte Sprache
#   * Type Hints als Unterstützung der IDE, damit diese Auto Completion anbieten kann
#     * Modul `typing`
#     * Type Hints werden zur Laufzeit **nicht** interpretiert
#   * Modul `typeguard`, um Typprüfungen zur Laufzeit durchführen zu können

# %% [markdown]
# #### Block 4: Weitere Objektorientierte Konzepte
# * Lernziele:
#   * Modellierung mit abstrakten und statischen Elementen
#   * Polymorphie
#   * Mixins, Mehrfachvererbung können separat eingeführt werden
# * Hinweise
#   * Die benutzten Decorators werden im nächsten Block behandelt, hier pragmatisch erläutern
#   * Das Klassenobjekt ist erfahrungsgemäß sehr hilfreich bei der Erläuterung
# * Übung:
#   * Auf Grundlage des `people`-Beispiels des Grundlagenkurses machen wir die Klasse `Person` abstrakt
#   * Dann können wir ein Protokoll einführen: `Adressable`, das `Person` aber auch `University` und `Company` implementieren
#   * Mixins und Mehrfachvererbung durchaus kritisch einführen

# %% [markdown]
# #### Block 5: Dynamische Konzepte der OOP
#
# * Lernziele:
#   * Meta-Programmierung
#   * Dekoration und Aspektorientierte Programmierung
# * Hinweise
#   * Hier ist wichtig die Teilnehmenden darauf hinzuweisen, dass diese Techniken insbesondere von Frameworks eingesetzt werden

# %% [markdown]
# #### Block 6: Testen
#
# * Lernziele:
#   * Grundbegriffe der Testgetriebenen Programmierung
#   * Schreiben von Unittests mit dem Modul `unittest`

# %% [markdown]
# #### Block 7: Anwendungsprogrammierung
#
# * Entity-Modell mit Publisher, Book, Author
# * Service-Klasse(n) mit Operationen
#   * Diskussion der Granularität der Services
# * Umsetzung
#   * Unittests nicht vergessen

# %% [markdown]
# #### Block 8: Anwendungsprogrammierung II
#
# * Lernziele
#   * Design Patterns
#   * Die "Klassiker" Singleton, Factory, Observer
#     * Dependency Injection als Meta-Pattern nicht vergessen!

# %% [markdown]
# #### Block 9: Client-Server
#
# * Lernziele
#   * Allgemeine Anmerkungen Threads / Child Processes
#   * Basic-Socket-Programmierung mit selbstgeschriebenem Multiprocessing Server

# %% [markdown]
# #### Block 10: RESTful WebServices
#
# * Lernziele
#   * REST
#   * Implementierung eines RESTful WebServices mit Flask

# %% [markdown]
# #### Block 11: GUI-Programmierung
#
# * Lernziele
#   * UI-Komponenten
#   * Implementierung einer mehr oder weniger einfachen Oberfläche mit Tkinter
# * Hinweis
#   * Ein optionales Füller-Kapitel zum Abschluss

# %% [markdown]
# #### Block 12: Abschluss
#
# * Zusammenfassung: "Wie weit sind wir gekommen"
# * Ausblick auf nicht-angesprochene / weiterführende Themen
# * Teilnehmenden-Feedback
