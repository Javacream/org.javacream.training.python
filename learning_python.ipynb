# %% [markdown]
# # Learning Python
#
# ## Variables

# %%
message = 'Hello'
message
# Out:
# 'Hello'

# %% [markdown]
# * message is a named variable
# * 'Hello' is a string literal
# * = is the assignement operator
