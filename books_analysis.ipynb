# %% [markdown]
# ## Aufgabenstellung
#
# Analysieren der Datei books.csv

# %% [markdown]
# * Schritt 1: Laden der Datei
# * Schritt 2: Prepare der Daten in einen DataFrame

# %%
import numpy as np 
import pandas as pd

# %%
books_data_frame = pd.read_csv('books.csv')
books_data_frame.rename(columns={'ISBN': 'isbn', 'Title': 'title', 'Price': 'books_price'})
# Out:
#         isbn                      title  books_price
# 0     ISBN-1                    Title 1           91
# 1     ISBN-2                    Title 2           15
# 2     ISBN-3                    Title 3           13
# 3     ISBN-4                    Title 4           91
# 4     ISBN-5                    Title 5           41
# ..       ...                        ...          ...
# 97   ISBN-95  Django – a Python Library           64
# 98   ISBN-96                   Title 99           78
# 99   ISBN-97                  Title 100           42
# 100  ISBN-98                  Title 101           67
# 101  ISBN-99                  Title 102           30
#
# [102 rows x 3 columns]

# %% [markdown]
# * Play with references

# %%
books_data_frame = pd.read_csv('books.csv')
df2 = books_data_frame.copy()
books_data_frame.rename(columns={'ISBN': 'isbn', 'Title': 'title', 'Price': 'books_price'}, inplace=True)
df2
# Out:
#         ISBN                      Title  Price
# 0     ISBN-1                    Title 1     91
# 1     ISBN-2                    Title 2     15
# 2     ISBN-3                    Title 3     13
# 3     ISBN-4                    Title 4     91
# 4     ISBN-5                    Title 5     41
# ..       ...                        ...    ...
# 97   ISBN-95  Django – a Python Library     64
# 98   ISBN-96                   Title 99     78
# 99   ISBN-97                  Title 100     42
# 100  ISBN-98                  Title 101     67
# 101  ISBN-99                  Title 102     30
#
# [102 rows x 3 columns]
