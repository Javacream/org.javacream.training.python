# %% [markdown]
# # Python Basics

# %% [markdown]
# ## Variables

# %%
message = 'Hello World'
print(message)
# Out:
# Hello World

# %%
print(message)
# Out:
# Hello World

# %%
message + 'Hugo'
# Out:
# 'Hello WorldHugo'
