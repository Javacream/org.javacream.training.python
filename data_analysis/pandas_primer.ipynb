# %% [markdown]
# # Die Pandas-Bibliothek

# %% [markdown]
# ## Überblick
#
# * de facto Standard für Datenanalyse-Programme in Python
# * Open Source
#   * Lizenzfrei in der Nutzung
#   * [Homepage](https://pandas.pydata.org/)
#   * [Dokumentation](https://pandas.pydata.org/docs/reference/index.html)
# * Funktionsumfang
#   * Unterstützung aller gängiger Datenformate, Lesend und Schreibend
#   * Spezielle Collection, der DataFrame
#   * Unterstützung von Grafiken = Diagrammen
#   * Integration der deskriptiven Statistik, also Mittelwerte, Abweichungen, ...
#   * Integration weiterer Bibliotheken, z.B. matplotlib, scikit für Machine Learning

# %% [markdown]
# ## Installation

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\raine\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\raine\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raine\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raine\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raine\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\raine\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Einführung in die Programmierung mit Pandas
#
# ### Import

# %%
import pandas as pd

# %% [markdown]
# ### Laden eines CSV-Datensatzes

# %%
pd.read_csv('PEOPLE.csv')
# Out:
#      id   firstname lastname  height  weight GENDER
# 0     1      Stacey   Miller    1.68    92.0      d
# 1     2       Carla   Gentry    1.68    85.4      d
# 2     3        Emma  Harding    1.75    98.2      d
# 3     4    Jeanette    Lopez    1.58    73.8      d
# 4     5      Edward    White    1.63    68.5      d
# ..  ...         ...      ...     ...     ...    ...
# 95   96  Jacqueline   Morris    1.54    99.8      d
# 96   97       Laura    Smith    1.66    50.1      d
# 97   98      Steven  Parrish    1.68    99.0      d
# 98   99     Stephen   Juarez    1.82    93.3      d
# 99  100    Courtney     Cruz    1.59    75.1      d
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Laden des Datensatzes und Zuweisung an eine Variable
#
# * Typ der Variable ist ein Pandas-DataFrame

# %%
df = pd.read_csv('PEOPLE.csv')
df
# Out:
#      id   firstname lastname  height  weight GENDER
# 0     1      Stacey   Miller    1.68    92.0      d
# 1     2       Carla   Gentry    1.68    85.4      d
# 2     3        Emma  Harding    1.75    98.2      d
# 3     4    Jeanette    Lopez    1.58    73.8      d
# 4     5      Edward    White    1.63    68.5      d
# ..  ...         ...      ...     ...     ...    ...
# 95   96  Jacqueline   Morris    1.54    99.8      d
# 96   97       Laura    Smith    1.66    50.1      d
# 97   98      Steven  Parrish    1.68    99.0      d
# 98   99     Stephen   Juarez    1.82    93.3      d
# 99  100    Courtney     Cruz    1.59    75.1      d
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Exploration des Datensatzes
#
# * head() und tail()
#   * Standard-Größe ist 5
#   * head(3)

# %%
df.head(3)
# Out:
#    id firstname lastname  height  weight GENDER
# 0   1    Stacey   Miller    1.68    92.0      d
# 1   2     Carla   Gentry    1.68    85.4      d
# 2   3      Emma  Harding    1.75    98.2      d

# %% [markdown]
# * info und describe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         100 non-null    int64
#  1   firstname  100 non-null    object
#  2   lastname   100 non-null    object
#  3   height     100 non-null    float64
#  4   weight     100 non-null    float64
#  5   GENDER     100 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#                id      height      weight
# count  100.000000  100.000000  100.000000
# mean    50.500000    1.739100   77.210000
# std     29.011492    0.135945   13.929342
# min      1.000000    1.510000   50.100000
# 25%     25.750000    1.627500   68.250000
# 50%     50.500000    1.755000   77.000000
# 75%     75.250000    1.830000   89.700000
# max    100.000000    1.990000   99.900000

# %% [markdown]
# * Unsaubere Eingangsdaten

# %%
dirty_df = pd.read_csv('PEOPLE_dirty.csv')
dirty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         100 non-null    int64
#  1   firstname  100 non-null    object
#  2   lastname   100 non-null    object
#  3   height     97 non-null     float64
#  4   weight     98 non-null     float64
#  5   GENDER     100 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
dirty_df = pd.read_csv('PEOPLE_very_dirty.csv')
dirty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         100 non-null    int64
#  1   firstname  100 non-null    object
#  2   lastname   100 non-null    object
#  3   height     97 non-null     object
#  4   weight     98 non-null     float64
#  5   GENDER     100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# ### DataFrame als Datencontainer / Collection

# %% [markdown]
# * Elementare Berechnungen / Zugriffe

# %%
height_series = df['height'] + 1

# %%
df['weight']/(df['height']**2)
# Out:
# 0     32.596372
# 1     30.257937
# 2     32.065306
# 3     29.562570
# 4     25.781926
#         ...
# 95    42.081295
# 96    18.181158
# 97    35.076531
# 98    28.166888
# 99    29.706103
# Length: 100, dtype: float64

# %%
bmi = df['weight']/(df['height']**2)
bmi
# Out:
# 0     32.596372
# 1     30.257937
# 2     32.065306
# 3     29.562570
# 4     25.781926
#         ...
# 95    42.081295
# 96    18.181158
# 97    35.076531
# 98    28.166888
# 99    29.706103
# Length: 100, dtype: float64

# %%
bmi.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 100 entries, 0 to 99
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 100 non-null    float64
# dtypes: float64(1)
# memory usage: 932.0 bytes

# %%
bmi.describe()
# Out:
# count    100.000000
# mean      25.889153
# std        5.793465
# min       13.295885
# 25%       22.496651
# 50%       24.580322
# 75%       29.796879
# max       42.081295
# dtype: float64

# %% [markdown]
# * Zuweisung einer Series an einen DataFrame

# %%
df['bmi'] = df['weight']/(df['height']**2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         100 non-null    int64
#  1   firstname  100 non-null    object
#  2   lastname   100 non-null    object
#  3   height     100 non-null    float64
#  4   weight     100 non-null    float64
#  5   GENDER     100 non-null    object
#  6   bmi        100 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# * Entfernen einer Series aus einem DataFrame

# %%
df.drop('GENDER', axis=1)
df.drop(columns=['GENDER'])
# Out:
#      id   firstname lastname  height  weight        bmi
# 0     1      Stacey   Miller    1.68    92.0  32.596372
# 1     2       Carla   Gentry    1.68    85.4  30.257937
# 2     3        Emma  Harding    1.75    98.2  32.065306
# 3     4    Jeanette    Lopez    1.58    73.8  29.562570
# 4     5      Edward    White    1.63    68.5  25.781926
# ..  ...         ...      ...     ...     ...        ...
# 95   96  Jacqueline   Morris    1.54    99.8  42.081295
# 96   97       Laura    Smith    1.66    50.1  18.181158
# 97   98      Steven  Parrish    1.68    99.0  35.076531
# 98   99     Stephen   Juarez    1.82    93.3  28.166888
# 99  100    Courtney     Cruz    1.59    75.1  29.706103
#
# [100 rows x 6 columns]

# %% [markdown]
# * Detail: inplace-Operationen

# %%
dropped = df.drop(columns=['GENDER'])
dropped
# Out:
#      id   firstname lastname  height  weight        bmi
# 0     1      Stacey   Miller    1.68    92.0  32.596372
# 1     2       Carla   Gentry    1.68    85.4  30.257937
# 2     3        Emma  Harding    1.75    98.2  32.065306
# 3     4    Jeanette    Lopez    1.58    73.8  29.562570
# 4     5      Edward    White    1.63    68.5  25.781926
# ..  ...         ...      ...     ...     ...        ...
# 95   96  Jacqueline   Morris    1.54    99.8  42.081295
# 96   97       Laura    Smith    1.66    50.1  18.181158
# 97   98      Steven  Parrish    1.68    99.0  35.076531
# 98   99     Stephen   Juarez    1.82    93.3  28.166888
# 99  100    Courtney     Cruz    1.59    75.1  29.706103
#
# [100 rows x 6 columns]

# %%
df.drop(columns=['GENDER'], inplace=True)
df
# Out:
#      id   firstname lastname  height  weight        bmi
# 0     1      Stacey   Miller    1.68    92.0  32.596372
# 1     2       Carla   Gentry    1.68    85.4  30.257937
# 2     3        Emma  Harding    1.75    98.2  32.065306
# 3     4    Jeanette    Lopez    1.58    73.8  29.562570
# 4     5      Edward    White    1.63    68.5  25.781926
# ..  ...         ...      ...     ...     ...        ...
# 95   96  Jacqueline   Morris    1.54    99.8  42.081295
# 96   97       Laura    Smith    1.66    50.1  18.181158
# 97   98      Steven  Parrish    1.68    99.0  35.076531
# 98   99     Stephen   Juarez    1.82    93.3  28.166888
# 99  100    Courtney     Cruz    1.59    75.1  29.706103
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Indexzugriff

# %%
df.index[0]
# Out:
# 0

# %%
print(type(df.loc))
sliced_df = df.loc[0:2, ['height', 'weight']]
sliced_df.describe()
# Out:
#          height     weight
# count  3.000000   3.000000
# mean   1.703333  91.866667
# std    0.040415   6.401042
# min    1.680000  85.400000
# 25%    1.680000  88.700000
# 50%    1.680000  92.000000
# 75%    1.715000  95.100000
# max    1.750000  98.200000

# %%
print(type(df.iloc))
sliced_df = df.iloc[0:2, 3]
sliced_df.describe()
# Out:
# <class 'pandas.core.indexing._iLocIndexer'>
# count    2.00
# mean     1.68
# std      0.00
# min      1.68
# 25%      1.68
# 50%      1.68
# 75%      1.68
# max      1.68
# Name: height, dtype: float64

# %% [markdown]
# ### Vergleichsoperatoren

# %%
df['height'] > 1.90
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: height, Length: 100, dtype: bool

# %%
selection_vector = df['height'] > 1.90
df[selection_vector]
# Out:
#     id firstname   lastname  height  weight        bmi
# 9   10     Brian      Brown    1.92    61.4  16.655816
# 22  23      Mary  Dickerson    1.91    95.4  26.150599
# 28  29  Margaret      Evans    1.96    86.5  22.516660
# 38  39  Kimberly      Jones    1.97    73.4  18.913139
# 40  41    Robert      Green    1.99    72.4  18.282367
# 46  47      Mary      Myers    1.99    73.4  18.534885
# 50  51    Cheryl      Young    1.95    90.4  23.773833
# 65  66     Jenny    Frazier    1.98    93.5  23.849607
# 73  74     James    Delgado    1.98    97.0  24.742373
# 76  77      Ryan       Lane    1.97    51.6  13.295885
# 79  80    Autumn     Watson    1.94    89.7  23.833564
# 80  81      Luis     Miller    1.92    83.1  22.542318
# 84  85   Jessica      Allen    1.98    97.3  24.818896
# 90  91    George      Jones    1.91    51.8  14.199172

# %%
df[df['height'] > 1.90]
# Out:
#     id firstname   lastname  height  weight        bmi
# 9   10     Brian      Brown    1.92    61.4  16.655816
# 22  23      Mary  Dickerson    1.91    95.4  26.150599
# 28  29  Margaret      Evans    1.96    86.5  22.516660
# 38  39  Kimberly      Jones    1.97    73.4  18.913139
# 40  41    Robert      Green    1.99    72.4  18.282367
# 46  47      Mary      Myers    1.99    73.4  18.534885
# 50  51    Cheryl      Young    1.95    90.4  23.773833
# 65  66     Jenny    Frazier    1.98    93.5  23.849607
# 73  74     James    Delgado    1.98    97.0  24.742373
# 76  77      Ryan       Lane    1.97    51.6  13.295885
# 79  80    Autumn     Watson    1.94    89.7  23.833564
# 80  81      Luis     Miller    1.92    83.1  22.542318
# 84  85   Jessica      Allen    1.98    97.3  24.818896
# 90  91    George      Jones    1.91    51.8  14.199172

# %%
tall_people_df = df[df['height'] > 1.90]
tall_people_df.describe()
# Out:
#               id     height     weight        bmi
# count  14.000000  14.000000  14.000000  14.000000
# mean   56.714286   1.955000  79.778571  20.864937
# std    25.838042   0.029807  16.061812   4.166524
# min    10.000000   1.910000  51.600000  13.295885
# 25%    39.500000   1.925000  72.650000  18.345496
# 50%    58.500000   1.965000  84.800000  22.529489
# 75%    79.250000   1.980000  92.725000  23.845596
# max    91.000000   1.990000  97.300000  26.150599

# %% [markdown]
# ### Lesen aus anderen Formaten und Quellen

# %% [markdown]
# * JSON

# %%
df = pd.read_json('http://javacream.eu:8080/people')
df
# Out:
#    id    lastname  firstname gender  height
# 0   1    Sawitzki     Rainer      m     183
# 1   2       Meier       Hans      m     163
# 2   3     Metzger      Georg      m     190
# 3   4     Metzger     Frieda      f     167
# 4   5    Hoffmann      Hanna      f     155
# 5   6  Pausenkurt     Pascal      m     177
# 6   7       Fisch      Wanda      f     164
# 7   8     Ziegler     Thomas      m     193
# 8   9        Tost  Franziska      f     177
# 9  10      Berger       Hans      m     183

# %%
df.describe()
# Out:
#              id      height
# count  10.00000   10.000000
# mean    5.50000  175.200000
# std     3.02765   12.532624
# min     1.00000  155.000000
# 25%     3.25000  164.750000
# 50%     5.50000  177.000000
# 75%     7.75000  183.000000
# max    10.00000  193.000000
