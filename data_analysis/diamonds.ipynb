# %% [markdown]
# ## Analyse des Diamenten-Datensatzes
#
# ### Prüfen der Python-Umgebung

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ### Einladen der notwendigen Bibliotheken, nämlich die pandas-Bibliothek
#
# * Hinweis: pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %% [markdown]
# ### Beginn der Analyse
#
# * Einladen der diamond.csv
# * Was für Daten haben wir denn?

# %%
df = pd.read_csv('./diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  \
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %% [markdown]
# ### Visualisierung der Carat-Verteilung in einem Histogramm

# %%
df.hist(column='carat', range=(0, 3.5), bins=15, color='green')
# Out:
# array([[<AxesSubplot:title={'center':'carat'}>]], dtype=object)

# %% [markdown]
# ### Ausreisser, carat > 3.5

# %%
df[df['carat'] > 3.5]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price      x
# 23644       23645   3.65       Fair     H      I1   67.1   53.0  11668   9.53  \
# 25998       25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14
# 25999       26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02
# 26444       26445   4.00  Very Good     I      I1   63.3   58.0  15984  10.01
# 26534       26535   3.67    Premium     I      I1   62.4   56.0  16193   9.86
# 27130       27131   4.13       Fair     H      I1   64.8   61.0  17329  10.00
# 27415       27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74
# 27630       27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23
# 27679       27680   3.51    Premium     J     VS2   62.5   59.0  18701   9.66
#
#            y     z
# 23644   9.48  6.38
# 25998  10.10  6.17
# 25999   9.94  6.24
# 26444   9.94  6.31
# 26534   9.81  6.13
# 27130   9.85  6.43
# 27415  10.54  6.98
# 27630  10.16  6.72
# ...

# %% [markdown]
# ### Dies und das...

# %%
df.hist(column='price')
# Out:
# array([[<AxesSubplot:title={'center':'price'}>]], dtype=object)

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000  \
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df.boxplot(column='carat')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='carat', by='clarity')
# Out:
# <AxesSubplot:title={'center':'carat'}, xlabel='clarity'>
