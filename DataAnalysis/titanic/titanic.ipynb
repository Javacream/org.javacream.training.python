# %% [markdown]
# # Titanic-Datensatz

# %% [markdown]
# ## Laden der einzelnen Datensätze

# %%
import pandas as pd

# %%
titanic_part1_df = pd.read_csv('titanic.csv')
titanic_part1_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_part2_incomplete_df = pd.read_csv('titanic_part2_incomplete.csv')
titanic_part2_incomplete_df.head()
# Out:
#    PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 0          951       1   Chaudanson, Miss. Victorine  female  36.0      0
# 1          952       3               Dika, Mr. Mirko    male  17.0      0
# 2          953       2     McCrae, Mr. Arthur Gordon    male  32.0      0
# 3          954       3  Bjorklund, Mr. Ernst Herbert    male  18.0      0
# 4          955       3  Bradley, Miss. Bridget Delia  female  22.0      0
#
#    Parch    Ticket      Fare Cabin Embarked
# 0      0  PC 17608  262.3750   B61        C
# 1      0    349232    7.8958   NaN        S
# 2      0    237216   13.5000   NaN        S
# 3      0    347090    7.7500   NaN        S
# 4      0    334914    7.7250   NaN        Q

# %%
titanic_part2_survival_df = pd.read_csv('titanic_part2_survival.csv')
titanic_part2_survival_df.head()
# Out:
#    PassengerId  Survived
# 0          951         0
# 1          952         0
# 2          953         0
# 3          954         0
# 4          955         0

# %% [markdown]
# ## Mergen der unvollständigen Daten

# %%
titanic_part2_df = pd.merge(titanic_part2_incomplete_df, titanic_part2_survival_df, how='inner', on='PassengerId')
titanic_part2_df.head()
# Out:
#    PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 0          951       1   Chaudanson, Miss. Victorine  female  36.0      0
# 1          952       3               Dika, Mr. Mirko    male  17.0      0
# 2          953       2     McCrae, Mr. Arthur Gordon    male  32.0      0
# 3          954       3  Bjorklund, Mr. Ernst Herbert    male  18.0      0
# 4          955       3  Bradley, Miss. Bridget Delia  female  22.0      0
#
#    Parch    Ticket      Fare Cabin Embarked  Survived
# 0      0  PC 17608  262.3750   B61        C         0
# 1      0    349232    7.8958   NaN        S         0
# 2      0    237216   13.5000   NaN        S         0
# 3      0    347090    7.7500   NaN        S         0
# 4      0    334914    7.7250   NaN        Q         0

# %% [markdown]
# ## Erzeugen des Gesamtdatensatzes

# %%
df = pd.concat([titanic_part1_df, titanic_part2_df], ignore_index=True)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1303         1305         0       3
# 1304         1306         0       1
# 1305         1307         0       3
# 1306         1308         0       3
# 1307         1309         1       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1303                                 Spector, Mr. Woolf    male   NaN      0
# 1304                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1305                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1306                                Ware, Mr. Frederick    male   NaN      0
# 1307                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1303      0           A.5. 3236    8.0500   NaN        S
# 1304      0            PC 17758  108.9000  C105        C
# 1305      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1306      0              359309    8.0500   NaN        S
# 1307      1                2668   22.3583   NaN        C
#
# [1308 rows x 12 columns]

# %% [markdown]
# ## Exploration

# %%
df.shape
# Out:
# (1308, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1308 non-null   int64
#  1   Survived     1308 non-null   int64
#  2   Pclass       1308 non-null   int64
#  3   Name         1308 non-null   object
#  4   Sex          1308 non-null   object
#  5   Age          1045 non-null   float64
#  6   SibSp        1308 non-null   int64
#  7   Parch        1308 non-null   int64
#  8   Ticket       1308 non-null   object
#  9   Fare         1307 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1306 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %%
df .describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1308.000000  1308.000000  1308.000000  1045.000000  1308.000000
# mean    654.819572     0.295872     2.294343    29.879110     0.499235
# std     378.108257     0.456608     0.837929    14.420245     1.041965
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     327.750000     0.000000     2.000000    21.000000     0.000000
# 50%     654.500000     0.000000     3.000000    28.000000     0.000000
# 75%     982.250000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1308.000000  1307.000000
# mean      0.385321    33.315024
# std       0.865826    51.773651
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148', 'B45', 'B36', 'A21', 'D34', 'A9', 'C31', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C55 C57', 'C116', 'F', 'A29', 'C6', 'C28',
#        'C51', 'C97', 'D22', 'B10', 'E45', 'E52', 'A11', 'B11', 'C80',
#        'C89', 'F E46', 'B26', 'F E57', 'A18', 'E60', 'E39 E41',
#        'B52 B54 B56', 'C39', 'B24', 'D40', 'D38', 'C105'], dtype=object)

# %% [markdown]
# * Folgerungen (subjektiv, es ist meine Analyse)
#   * Es gibt Lücken in den Datensätzen
#   * PassengerID ist redundant, wir haben ja bereits den Index
#   * Ticket ist im Wesentlichen ein "Zufallswert" ohne weitere Bedeutung
#   * Survival ist eigentlich ein logischer Wert, 0=Tot, 1=überlebt
#   * Pclass = Passenger Class hat nur die Werte 1st, 2nd, 3rd, ist kategorisch
#   * Sex, Embarked = Zustiegspunkt ebenfalls eine kategorische Variable
#   * Cabin hat einen interessanten Aufbau, Zeichenkette + Nummer
#   * Parch /Sibsp: Anzahl der Eltern Kinder bzw. Angehörige

# %% [markdown]
# ## Cleanup

# %% [markdown]
# * Lücken in den Daten werden behoben
#   * Alter wird durch das mittlere Passagier-Alter ersetzt
#   * Embarked 'Unknown'
# * Die Spalten PassengerID und Ticket sind unnötig
# * Survival durch eine logische Spalte ersetzen oder als eine kategorische Variable definieren
# * Pclass muss categorial sein
# * Sex, Embarked, ebenfalls categorial machen
# * Cabin wird in 2 neue Spalten zerlegt: Bereich der Titanic (Anfangsbuchstabe) und die Kabinennummer als Ganzzahl

# %% [markdown]
# ### Löschen der überflüssigen Spalten

# %%
df.drop('PassengerId', axis=1, inplace=True)
df.drop('Ticket', axis=1, inplace=True)

# %% [markdown]
# ### Setzen eines unbekannten Alters auf das Durchschnittsalter
# * Erweiterung: Durchschnittsalter für Frauen und Männer getrennt

# %%
df.loc[(df['Sex'] == 'female') & (df['Age'].isnull())]
# Out:
#       Survived  Pclass                                            Name  \
# 19           1       3                         Masselmani, Mrs. Fatima
# 28           1       3                   O'Dwyer, Miss. Ellen "Nellie"
# 31           1       1  Spencer, Mrs. William Augustus (Marie Eugenie)
# 32           1       3                        Glynn, Miss. Mary Agatha
# 47           1       3                       O'Driscoll, Miss. Bridget
# ...        ...     ...                                             ...
# 1194         0       3               McCarthy, Miss. Catherine Katie""
# 1255         0       3                  Sage, Mrs. John (Annie Bullen)
# 1272         0       3                      Risien, Mrs. Samuel (Emma)
# 1298         0       3                 Riordan, Miss. Johanna Hannah""
# 1300         0       3                          Naughton, Miss. Hannah
#
#          Sex  Age  SibSp  Parch      Fare Cabin Embarked
# 19    female  NaN      0      0    7.2250   NaN        C
# 28    female  NaN      0      0    7.8792   NaN        Q
# 31    female  NaN      1      0  146.5208   B78        C
# 32    female  NaN      0      0    7.7500   NaN        Q
# 47    female  NaN      0      0    7.7500   NaN        Q
# ...      ...  ...    ...    ...       ...   ...      ...
# 1194  female  NaN      0      0    7.7500   NaN        Q
# 1255  female  NaN      1      9   69.5500   NaN        S
# 1272  female  NaN      0      0   14.5000   NaN        S
# 1298  female  NaN      0      0    7.7208   NaN        Q
# 1300  female  NaN      0      0    7.7500   NaN        Q
#
# [78 rows x 10 columns]

# %%
male_mean_age = df[df['Sex'] == 'male']['Age'].mean()
female_mean_age = df[df['Sex'] == 'female']['Age'].mean()

df.loc[(df['Sex'] == 'female') & (df['Age'].isnull()), 'Age'] = female_mean_age
df.loc[(df['Sex'] == 'male') & (df['Age'].isnull()), 'Age'] = male_mean_age

# %% [markdown]
# ### Setzen unbekannter Zustiegspunkte

# %%
df.loc[df['Embarked'].isnull(), 'Embarked'] = 'U'

# %% [markdown]
# ### Erstellung der Categorial Columns

# %% [markdown]
# ### Überlebt

# %%
surviced_categorical_series = pd.Categorical(df['Survived'])
surviced_categorical_series = surviced_categorical_series.rename_categories(['died', 'survived'])
df['Survived'] = surviced_categorical_series
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1308 non-null   category
#  1   Pclass    1308 non-null   int64
#  2   Name      1308 non-null   object
#  3   Sex       1308 non-null   object
#  4   Age       1308 non-null   float64
#  5   SibSp     1308 non-null   int64
#  6   Parch     1308 non-null   int64
#  7   Fare      1307 non-null   float64
#  8   Cabin     295 non-null    object
#  9   Embarked  1308 non-null   object
# dtypes: category(1), float64(2), int64(3), object(4)
# memory usage: 93.5+ KB

# %% [markdown]
# ### Embarked, Sex, Pclass

# %%
df['Sex'] = pd.Categorical(df['Sex'])
df['Pclass'] = pd.Categorical(df['Pclass']).rename_categories({1: 'First', 2: 'Second', 3: 'Third'})
stations = {'S': 'Southhampton', 'C': 'Cherbourg', 'Q': 'Queenstown', 'U': 'Unknown'}
embarked_categorical = pd.Categorical(df['Embarked']).rename_categories(stations)
df['Embarked'] = embarked_categorical

# %% [markdown]
# ### Split der Kabineninformation, Extrahieren des Bereichs im Schiff

# %%
df.loc[df['Cabin'].isna(), 'Cabin'] = 'Z'
cabin_area = [cabin[0] for cabin in df['Cabin']]
cabin_area_series = pd.Series(cabin_area)
df['Cabin'] = pd.Categorical(cabin_area_series)

# %% [markdown]
# ### Endergebnis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1308 non-null   category
#  1   Pclass    1308 non-null   category
#  2   Name      1308 non-null   object
#  3   Sex       1308 non-null   category
#  4   Age       1308 non-null   float64
#  5   SibSp     1308 non-null   int64
#  6   Parch     1308 non-null   int64
#  7   Fare      1307 non-null   float64
#  8   Cabin     1308 non-null   category
#  9   Embarked  1308 non-null   category
# dtypes: category(5), float64(2), int64(2), object(1)
# memory usage: 58.5+ KB

# %%
df
# Out:
#       Survived Pclass                                               Name  \
# 0         died  Third                            Braund, Mr. Owen Harris
# 1     survived  First  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     survived  Third                             Heikkinen, Miss. Laina
# 3     survived  First       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         died  Third                           Allen, Mr. William Henry
# ...        ...    ...                                                ...
# 1303      died  Third                                 Spector, Mr. Woolf
# 1304      died  First                       Oliva y Ocana, Dona. Fermina
# 1305      died  Third                       Saether, Mr. Simon Sivertsen
# 1306      died  Third                                Ware, Mr. Frederick
# 1307  survived  Third                           Peter, Master. Michael J
#
#          Sex        Age  SibSp  Parch      Fare Cabin      Embarked
# 0       male  22.000000      1      0    7.2500     Z  Southhampton
# 1     female  38.000000      1      0   71.2833     C     Cherbourg
# 2     female  26.000000      0      0    7.9250     Z  Southhampton
# 3     female  35.000000      1      0   53.1000     C  Southhampton
# 4       male  35.000000      0      0    8.0500     Z  Southhampton
# ...      ...        ...    ...    ...       ...   ...           ...
# 1303    male  30.583075      0      0    8.0500     Z  Southhampton
# 1304  female  39.000000      0      0  108.9000     C     Cherbourg
# 1305    male  38.500000      0      0    7.2500     Z  Southhampton
# 1306    male  30.583075      0      0    8.0500     Z  Southhampton
# 1307    male  30.583075      1      1   22.3583     Z     Cherbourg
#
# [1308 rows x 10 columns]

# %% [markdown]
# ## Datenanalyse und -visualisierung

# %% [markdown]
# * Datenverarbeitung dieser Daten "wie üblich" mit Erzeugen einer Ergebnis-Datei
#   * "Ich hätte gerne eine Liste aller Passagiere, die in Southhampton eingestiegen sind, über dreissig Jahre, überlebt"
#   * Mittelwert des Alters der Passagiere
#   * Mittelwert des Alters der Passagiere, die überlebt haben
#   * ...
# * Erstellung von Diagrammen
#   * z.B. ein Histogramm des Alters
#   * z.B. ein Histogramm des Alters der Überlebenden
#   * Boxplot zur Visualisierung elementarer Statistik-Informationen

# %%
df.hist('Age')
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
df.hist(color = 'red')
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>],
#        [<Axes: title={'center': 'Parch'}>,
#         <Axes: title={'center': 'Fare'}>]], dtype=object)

# %%
df.hist('Age', bins=10, by='Pclass')
# Out:
# C:\Users\raine\AppData\Local\Temp\ipykernel_14308\3751961733.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.hist('Age', bins=10, by='Pclass')
# array([[<Axes: title={'center': 'First'}>,
#         <Axes: title={'center': 'Second'}>],
#        [<Axes: title={'center': 'Third'}>, <Axes: >]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >
