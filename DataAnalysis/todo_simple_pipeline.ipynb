# %% [markdown]
# # Aufgabe
#
# * Lesen der Daten aus einem WebService (oder der lokalen people.json)
# * Schreiben der Daten in die Datei people_from_web.csv

# %%
import pandas as pd
df = pd.read_json('http://javacream.eu:8080/people')
df.to_csv('people_from_web.csv')
