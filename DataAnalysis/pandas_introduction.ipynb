# %% [markdown]
# # Einführung in die Pandas-Bibliothek

# %% [markdown]
# ## Bibliotheken importieren

# %%
import pandas as pd

# %% [markdown]
# * Check: Pandas wurde geladen durch Ausgabe des pd-Objekts
#   * Hinweis: Die Python-Umgebung wird pro Notebook gestartet, damit stellen bereits ausgeführte Zellen Objekte, Funktionen etc. bereit

# %%
print(pd)
# Out:
# <module 'pandas' from 'c:\\Users\\raine\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# ## Eigenschaften des Pandas-Objekts
#
# * Hinweis
#   * Das pandas-Objekt ist ziemlich unstrukturiert, unübersichtlich, überladen
#   * Es wäre besser gewesen, das Pandas-Objekt noch mit Unterobjekten zu strukturieren
#      * Beispiel
#          * So ist es:
#            * pd.read_csv('path')
#          * So fände ich es besser:
#            * pd.reader.csv('path')
#            * pd.statistics.mean

# %%
# pd.c # Code Assist in Visual Studio Code

# %% [markdown]
# ## Exploration von Daten

# %% [markdown]
# * Das Einlesen der Daten erfolt mit den read_xyz-Methoden

# %%
pd.read_csv('people.csv')
# Out:
#      lastname  firstname  height_cm  weight_kg
# 0      Müller     Thomas      197.0        NaN
# 1     Schmidt    Michael      192.0       50.0
# 2   Schneider    Andreas      191.0        NaN
# 3     Fischer     Stefan      195.0       70.0
# 4       Weber  Christian      185.0       73.0
# 5       Meyer     Markus      183.0       67.0
# 6      Wagner     Daniel        NaN      116.0
# 7      Becker      Kevin      193.0      113.0
# 8      Schulz     Sascha      197.0      117.0
# 9    Hoffmann       Jens      193.0        NaN
# 10       Koch     Oliver        NaN       82.0
# 11      Bauer    Patrick      165.0       93.0
# 12    Richter        Jan        NaN        NaN
# 13      Klein     Tobias      168.0       63.0
# 14       Wolf  Sebastian      165.0        NaN
# 15   Schröder  Alexander      187.0       64.0
# 16    Neumann     Dennis        NaN       94.0
# 17      Braun      Frank        NaN        NaN
# 18    Schwarz        Tim      176.0       55.0
# ...

# %% [markdown]
# ### Exkurs: Out-Zellen und Python-Programme
#
# * Das Ergebnis der letzten Anweisung wird automatisch in den Out-Bereich geschrieben
# * Formatierung übernimmt das Notebook speziell für die unterstützten Datentypem
# * Das normale print funktioniert, allerdings ist das Ergebnis unformatiert

# %%
message = 'Hello'
print(message)
new_message = message + ' World'
new_message
# Out:
# Hello
# 'Hello World'

# %% [markdown]
# * Richtiges Einlesen der Daten
#   * Zuweisung an eine DataFrame-Variable

# %%
df = pd.read_csv('people.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Methoden des DataFrame

# %%
df.head()
# Out:
#     lastname  firstname  height_cm  weight_kg
# 0     Müller     Thomas      197.0        NaN
# 1    Schmidt    Michael      192.0       50.0
# 2  Schneider    Andreas      191.0        NaN
# 3    Fischer     Stefan      195.0       70.0
# 4      Weber  Christian      185.0       73.0

# %%
df.tail()
# Out:
#     lastname  firstname  height_cm  weight_kg
# 15  Schröder  Alexander      187.0       64.0
# 16   Neumann     Dennis        NaN       94.0
# 17     Braun      Frank        NaN        NaN
# 18   Schwarz        Tim      176.0       55.0
# 19    Krüger      Lukas      178.0       58.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lastname   20 non-null     object
#  1   firstname  20 non-null     object
#  2   height_cm  15 non-null     float64
#  3   weight_kg  14 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 772.0+ bytes

# %%
df.describe()
# Out:
#         height_cm   weight_kg
# count   15.000000   14.000000
# mean   184.333333   79.642857
# std     11.405930   23.193524
# min    165.000000   50.000000
# 25%    177.000000   63.250000
# 50%    187.000000   71.500000
# 75%    193.000000   93.750000
# max    197.000000  117.000000

# %% [markdown]
# * DataFrame Operationen

# %%
# f'{df['lastname']}  {df['firstname']}' # Keine String-Interpolation
calculated_series = df['firstname'] + " " + df['lastname']
df['fullname'] = calculated_series
df
df['fullname2'] = df['lastname'] + " " + df['firstname']
df 
df['fullname3'] = df.lastname + "->" + df.firstname
df
# Out:
#      lastname  firstname  height_cm  weight_kg            fullname  \
# 0      Müller     Thomas      197.0        NaN       Thomas Müller
# 1     Schmidt    Michael      192.0       50.0     Michael Schmidt
# 2   Schneider    Andreas      191.0        NaN   Andreas Schneider
# 3     Fischer     Stefan      195.0       70.0      Stefan Fischer
# 4       Weber  Christian      185.0       73.0     Christian Weber
# 5       Meyer     Markus      183.0       67.0        Markus Meyer
# 6      Wagner     Daniel        NaN      116.0       Daniel Wagner
# 7      Becker      Kevin      193.0      113.0        Kevin Becker
# 8      Schulz     Sascha      197.0      117.0       Sascha Schulz
# 9    Hoffmann       Jens      193.0        NaN       Jens Hoffmann
# 10       Koch     Oliver        NaN       82.0         Oliver Koch
# 11      Bauer    Patrick      165.0       93.0       Patrick Bauer
# 12    Richter        Jan        NaN        NaN         Jan Richter
# ...

# %% [markdown]
# * Entfernen von Spalten

# %%
# df.drop('fullname3', axis=1, inplace=True)
#df.drop('fullname3', axis=1)
#df

df.drop('fullname3', axis=1)
# Out:
#      lastname  firstname  height_cm  weight_kg            fullname  \
# 0      Müller     Thomas      197.0        NaN       Thomas Müller
# 1     Schmidt    Michael      192.0       50.0     Michael Schmidt
# 2   Schneider    Andreas      191.0        NaN   Andreas Schneider
# 3     Fischer     Stefan      195.0       70.0      Stefan Fischer
# 4       Weber  Christian      185.0       73.0     Christian Weber
# 5       Meyer     Markus      183.0       67.0        Markus Meyer
# 6      Wagner     Daniel        NaN      116.0       Daniel Wagner
# 7      Becker      Kevin      193.0      113.0        Kevin Becker
# 8      Schulz     Sascha      197.0      117.0       Sascha Schulz
# 9    Hoffmann       Jens      193.0        NaN       Jens Hoffmann
# 10       Koch     Oliver        NaN       82.0         Oliver Koch
# 11      Bauer    Patrick      165.0       93.0       Patrick Bauer
# 12    Richter        Jan        NaN        NaN         Jan Richter
# ...

# %%
df['bmi'] = df.weight_kg / (df.height_cm*df.height_cm) * 10000
df
# Out:
#      lastname  firstname  height_cm  weight_kg            fullname  \
# 0      Müller     Thomas      197.0        NaN       Thomas Müller
# 1     Schmidt    Michael      192.0       50.0     Michael Schmidt
# 2   Schneider    Andreas      191.0        NaN   Andreas Schneider
# 3     Fischer     Stefan      195.0       70.0      Stefan Fischer
# 4       Weber  Christian      185.0       73.0     Christian Weber
# 5       Meyer     Markus      183.0       67.0        Markus Meyer
# 6      Wagner     Daniel        NaN      116.0       Daniel Wagner
# 7      Becker      Kevin      193.0      113.0        Kevin Becker
# 8      Schulz     Sascha      197.0      117.0       Sascha Schulz
# 9    Hoffmann       Jens      193.0        NaN       Jens Hoffmann
# 10       Koch     Oliver        NaN       82.0         Oliver Koch
# 11      Bauer    Patrick      165.0       93.0       Patrick Bauer
# 12    Richter        Jan        NaN        NaN         Jan Richter
# ...

# %% [markdown]
# ### Cleanup

# %%
df.fillna(4711)
# Out:
#      lastname  firstname  height_cm  weight_kg            fullname  \
# 0      Müller     Thomas      197.0     4711.0       Thomas Müller
# 1     Schmidt    Michael      192.0       50.0     Michael Schmidt
# 2   Schneider    Andreas      191.0     4711.0   Andreas Schneider
# 3     Fischer     Stefan      195.0       70.0      Stefan Fischer
# 4       Weber  Christian      185.0       73.0     Christian Weber
# 5       Meyer     Markus      183.0       67.0        Markus Meyer
# 6      Wagner     Daniel     4711.0      116.0       Daniel Wagner
# 7      Becker      Kevin      193.0      113.0        Kevin Becker
# 8      Schulz     Sascha      197.0      117.0       Sascha Schulz
# 9    Hoffmann       Jens      193.0     4711.0       Jens Hoffmann
# 10       Koch     Oliver     4711.0       82.0         Oliver Koch
# 11      Bauer    Patrick      165.0       93.0       Patrick Bauer
# 12    Richter        Jan     4711.0     4711.0         Jan Richter
# ...

# %% [markdown]
# ### Exkurs: Selektion von Daten im DataFrame mit Pandas
#
# * Beispiel: Selektion nach Körpergröße

# %%
criteria_series = df['height_cm'] > 190
df[criteria_series]
# Out:
#     lastname firstname  height_cm  weight_kg           fullname  \
# 0     Müller    Thomas      197.0        NaN      Thomas Müller
# 1    Schmidt   Michael      192.0       50.0    Michael Schmidt
# 2  Schneider   Andreas      191.0        NaN  Andreas Schneider
# 3    Fischer    Stefan      195.0       70.0     Stefan Fischer
# 7     Becker     Kevin      193.0      113.0       Kevin Becker
# 8     Schulz    Sascha      197.0      117.0      Sascha Schulz
# 9   Hoffmann      Jens      193.0        NaN      Jens Hoffmann
#
#            fullname2           fullname3        bmi
# 0      Müller Thomas      Müller->Thomas        NaN
# 1    Schmidt Michael    Schmidt->Michael  13.563368
# 2  Schneider Andreas  Schneider->Andreas        NaN
# 3     Fischer Stefan     Fischer->Stefan  18.408941
# 7       Becker Kevin       Becker->Kevin  30.336385
# 8      Schulz Sascha      Schulz->Sascha  30.147646
# 9      Hoffmann Jens      Hoffmann->Jens        NaN

# %%
df[df['height_cm'] > 190]
# Out:
#     lastname firstname  height_cm  weight_kg           fullname  \
# 0     Müller    Thomas      197.0        NaN      Thomas Müller
# 1    Schmidt   Michael      192.0       50.0    Michael Schmidt
# 2  Schneider   Andreas      191.0        NaN  Andreas Schneider
# 3    Fischer    Stefan      195.0       70.0     Stefan Fischer
# 7     Becker     Kevin      193.0      113.0       Kevin Becker
# 8     Schulz    Sascha      197.0      117.0      Sascha Schulz
# 9   Hoffmann      Jens      193.0        NaN      Jens Hoffmann
#
#            fullname2           fullname3        bmi
# 0      Müller Thomas      Müller->Thomas        NaN
# 1    Schmidt Michael    Schmidt->Michael  13.563368
# 2  Schneider Andreas  Schneider->Andreas        NaN
# 3     Fischer Stefan     Fischer->Stefan  18.408941
# 7       Becker Kevin       Becker->Kevin  30.336385
# 8      Schulz Sascha      Schulz->Sascha  30.147646
# 9      Hoffmann Jens      Hoffmann->Jens        NaN
