# %% [markdown]
# # Python 3 - Grundlagen der Programmierung
# ## Ein Lernpfad von [Javacream](http://javacream.org)

# %% [markdown]
# ### First Contact
#
# Mit der `print`-Anweisung wird Text auf die Konsole ausgegeben

# %%
print('Hello World')
# Out:
# Hello World
