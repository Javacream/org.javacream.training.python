# %% [markdown]
# # Datenquellen
#
# ## Kategorien
#
# ### Datenbanksysteme
#
# * Halten Geschäftsdaten in einer konsistenten Form
# * Selektion der Daten aus der Datenbank z.B. mit SQL
# * Viele andere Datenbanksysteme existieren mit Abfragesprachen wie N1QL, gesprochen "Nickel"
#
# ### REST-Schnittstellen
#
# * Zugriff auf einen sogenannten RESTful WebService
#   * Heute quasi die absolute Majorität der Daten
#   * Geschäftsdaten, Log-Dateien, Metrik-Informationen zur Überwachung, Sensoren, ...
#
#   * Beispiel

# %%
import pandas as pd
pd.read_json('people.json')

# %%
pd.read_json('http://javacream.eu:8080/people')

# %%
pd.read_csv('https://raw.githubusercontent.com/lawlesst/vivo-sample-data/refs/heads/master/data/csv/people.csv')
# Out:
#     person_ID                        name      first      last      middle  \
# 0        3130             Burks, Rosella     Rosella     Burks         NaN
# 1        3297              Avila, Damien      Damien     Avila         NaN
# 2        3547               Olsen, Robin       Robin     Olsen         NaN
# 3        1538         Moises, Edgar Estes      Edgar    Moises       Estes
# 4        2941         Brian, Heath Pruitt      Heath     Brian      Pruitt
# 5        2401         Claude, Elvin Haney      Elvin    Claude       Haney
# 6        2070             Mosley, Edmund      Edmund    Mosley         NaN
# 7        2561        Derek, Antoine Mccoy    Antoine     Derek       Mccoy
# 8        1625            Hawkins, Callie      Callie   Hawkins         NaN
# 9        1307               Pate, Andrea      Andrea      Pate         NaN
# 10       2342                Austin, Liz         Liz    Austin         NaN
# ...

# %% [markdown]
# ### Idee für ein Todo
#
# * Schritte zum Auslesen einer Datenbank-Tabelle?
#   * Welcher Datenbank-Hersteller?
#     * Installation des notwendigen Treibers
#     * z.B. pip install mysql-connector-python
#   * Aufbauen einer Connextion mit Informationen user, password, db-name, endpoint
#   * Welche Tabelle enthält die Daten?
#     select * from people

# %%
import mysql.connector

connection = mysql.connector.connect(
    host='javacream.eu', 
    port=3406, 
    database='javacream', 
    user='user', 
    password='user'
)

pd.read_sql('select id, lastname, firstname from PEOPLE', connection)
# Out:
# C:\Users\raine\AppData\Local\Temp\ipykernel_7660\3153863912.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('select id, lastname, firstname from PEOPLE', connection)
#    id      lastname firstname
# 0   1      Sawitzki    Rainer
# 1   2  Musterperson    Andrea
# 2   3     Schneider    Hannah
