# %% [markdown]
# # ToDo
#
# * Allgemeines
#     * Einlesen des Datensatzes titanic.csv
#     * Einlesen des Datensatzes titanic_part2_incomplete.csv
#         * Es fehlt "verstorben oder nicht"
#     * Einlesen des Datensatzes titanic_part2_survival.csv
#
# * Aufgabe 1
#     * incomplete mit der survival zusammenfügen!
#       * Hinweis: pd.merge-Methode
#     * titanic mit diesen Daten zusammenfügen = Konkatinieren = pd.concat
# * Aufgabe 2
#     * Datenexploration
#       * Gibt es Null-Werte?
#        * Unbekannte Age-Werte sollen ersetzt werden mit dem Durchschnittsalter der restlichen Passagiere, gerne noch unterteilt in Frauen und Männer
#        * Unbekannte Zustiegspunkte (embarked) sollen mit 'U'
#         * Gibt es überflüssige / redundante Spalten
#         * Wir haben ja eh einen Zeilenindex, PassengerId?
#         * Ticket = Ticketnummer: hat das irgendwelchen Wert?
#         * Was sind denn Kandidaten für kategorische Variablen?
#         * Hinweis: Hier gibt es eine unique-Methode
#         * Eine Spalte mit diskreten Werten kann mit pd.Categorical entsprechend gekennzeichnet werden
#             * df.info() -> object-Spalte ist Freitext, kontinuierlich
#         * Die Cabin-Variable ist interessant
#             * Innere Struktur: Buchstabe = Bereich des Schiffes, Kabinennummer als numerischer Wert
#             * Einführen zweier Spalten wäre möglich
# * Aufgabe 3
#     * Visualisierung
#     * Boxplots der numerischen Werte
#     * Histogramme
