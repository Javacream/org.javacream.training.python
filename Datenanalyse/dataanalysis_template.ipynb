# %% [markdown]
# ### Schritt 1
#
# * import, read

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('people.csv')

# %% [markdown]
# ### Exploration
#
# head(), info(), shape

# %%
df.head()
# Out:
#     lastname  firstname  height_cm  weight_kg
# 0     Müller     Thomas      197.0        NaN
# 1    Schmidt    Michael      192.0       50.0
# 2  Schneider    Andreas      191.0        NaN
# 3    Fischer     Stefan      195.0       70.0
# 4      Weber  Christian      185.0       73.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lastname   21 non-null     object
#  1   firstname  21 non-null     object
#  2   height_cm  16 non-null     float64
#  3   weight_kg  15 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 804.0+ bytes

# %%
df.shape
# Out:
# (21, 4)

# %% [markdown]
# * Ergebnisse der Explorationsphase
#   * Größe und Gewicht werden korrekt als Zahlen erkannt
#   * NaN-Werte

# %% [markdown]
# * Anzeige von NaN
#   * df.isna

# %%
df['height_cm'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# Name: height_cm, dtype: bool

# %% [markdown]
# ## Cleanup
#
# * Kovertierungen (hier nicht notwendig)
# * Umgang mit den NaN-Werten
#   * dropna(), fillna()

# %%
df.dropna()
# Out:
#     lastname  firstname  height_cm  weight_kg
# 1    Schmidt    Michael      192.0       50.0
# 3    Fischer     Stefan      195.0       70.0
# 4      Weber  Christian      185.0       73.0
# 5      Meyer     Markus      183.0       67.0
# 7     Becker      Kevin      193.0      113.0
# 8     Schulz     Sascha      197.0      117.0
# 11     Bauer    Patrick      165.0       93.0
# 13     Klein     Tobias      168.0       63.0
# 15  Schröder  Alexander      187.0       64.0
# 18   Schwarz        Tim      176.0       55.0
# 19    Krüger      Lukas      178.0       58.0
# 20  Sawitzki     Rainer       16.0       88.8

# %%
df.fillna({'height_cm': 181, 'weight_kg': 77.7})
# Out:
#      lastname  firstname  height_cm  weight_kg
# 0      Müller     Thomas      197.0       77.7
# 1     Schmidt    Michael      192.0       50.0
# 2   Schneider    Andreas      191.0       77.7
# 3     Fischer     Stefan      195.0       70.0
# 4       Weber  Christian      185.0       73.0
# 5       Meyer     Markus      183.0       67.0
# 6      Wagner     Daniel      181.0      116.0
# 7      Becker      Kevin      193.0      113.0
# 8      Schulz     Sascha      197.0      117.0
# 9    Hoffmann       Jens      193.0       77.7
# 10       Koch     Oliver      181.0       82.0
# 11      Bauer    Patrick      165.0       93.0
# 12    Richter        Jan      181.0       77.7
# 13      Klein     Tobias      168.0       63.0
# 14       Wolf  Sebastian      165.0       77.7
# 15   Schröder  Alexander      187.0       64.0
# 16    Neumann     Dennis      181.0       94.0
# 17      Braun      Frank      181.0       77.7
# 18    Schwarz        Tim      176.0       55.0
# ...

# %% [markdown]
# ### Ausstiegspunkt 1
# * Die gesäuberten Daten werden gespeichert

# %%
cleaned = df.fillna({'height_cm': 181, 'weight_kg': 77.7})

cleaned.to_csv('cleaned_people.csv')

# %% [markdown]
# ## Aufbereiten
#
# * Zusammenfassen und Berechnen von Spalten

# %%
df['name'] = df['firstname'] +' ' + df['lastname']
# df['bmi'] = ...

# %% [markdown]
# ### Ausstiegspunkt 2
#
# * Die aufbereiteten Daten werden gespeichert

# %% [markdown]
# ### Analyse
#
# * Statitistische Werte
#     * Mittelwerte
#     * Standardabweichung
#     * df.describe()

# %%
df.describe()
# Out:
#         height_cm   weight_kg
# count   16.000000   15.000000
# mean   173.812500   80.253333
# std     43.502059   22.474553
# min     16.000000   50.000000
# 25%    174.000000   63.500000
# 50%    186.000000   73.000000
# 75%    193.000000   93.500000
# max    197.000000  117.000000

# %%
df['height_cm'].mean()
# Out:
# np.float64(173.8125)

# %% [markdown]
# * Visualisierung

# %%
df.boxplot(column='height_cm')
# Out:
# <Axes: >

# %%
df[(df['height_cm'] > 120) & (df['height_cm'] < 195)]
# df.drop(df[(df['height_cm'] < 120) | (df['height_cm'] > 195)].index)
# Out:
#      lastname  firstname  height_cm  weight_kg                name
# 1     Schmidt    Michael      192.0       50.0     Michael Schmidt
# 2   Schneider    Andreas      191.0        NaN   Andreas Schneider
# 3     Fischer     Stefan      195.0       70.0      Stefan Fischer
# 4       Weber  Christian      185.0       73.0     Christian Weber
# 5       Meyer     Markus      183.0       67.0        Markus Meyer
# 6      Wagner     Daniel        NaN      116.0       Daniel Wagner
# 7      Becker      Kevin      193.0      113.0        Kevin Becker
# 9    Hoffmann       Jens      193.0        NaN       Jens Hoffmann
# 10       Koch     Oliver        NaN       82.0         Oliver Koch
# 11      Bauer    Patrick      165.0       93.0       Patrick Bauer
# 12    Richter        Jan        NaN        NaN         Jan Richter
# 13      Klein     Tobias      168.0       63.0        Tobias Klein
# 14       Wolf  Sebastian      165.0        NaN      Sebastian Wolf
# ...
