# %% [markdown]
# # Der Books Datenbestand

# %% [markdown]
# ## Laden des Bestandes aus der SQLite Datenbank books.db

# %%
import sqlite3

# %%
connection = sqlite3.connect('books.db')
connection

# %%
cursor = connection.cursor()
cursor

# %% [markdown]
# ## Anzeigen eines Datensatzes

# %%
cursor.execute("select * from books")
cursor.fetchone()
# Out:
# ('1216387044038', 'Book Title 1', 22.82, 828)

# %% [markdown]
# ## Anzahl der Datensätze
