# %% [markdown]
# # Python Grundlagen.
#
# ## Variablen und Operatoren
#
# * Zur Definition einer Variablen in Python wird ein Wert zugewiesen

# %%
message = 'Hello'
number = 9

# %% [markdown]
# * Variablen können mit der **BuildIn-Funktion** `print` ausgegeben werden:

# %%
print(message)
# Out:
# Hello
