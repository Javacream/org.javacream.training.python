# %% [markdown]
# # Grundlagen der Python-Programmierung
#
# ## Variablen und BuiltIn-Funktionen

# %% [markdown]
# * Definition einer Variable
# * Ausgabe auf die Konsole

# %%
message = 'Hello'
print(message)
# Out:
# Hello

# %% [markdown]
# * Ein paar Details zu den Code Cells
#   * Implizite Ausgaben

# %%
message = 'Hello World'
message
# Out:
# 'Hello World'

# %%
def do_something():
    return 'done'

do_something()
message = 'Egal'

# %% [markdown]
#   * Der Kernel läuft, bis das Notebook geschlossen ist oder der Kernel neu gestartet wird

# %%
message
# Out:
# 'Egal'
