# %% [markdown]
# # Markdown
#
# ## Überblick
#
# Intention ist die Bereitstellung einer simplen und einfach zu lernenden Sprache zum Erstellen formatierter Texte

# %% [markdown]
# ## Basis-Syntax
#
# [Reference Card](https://www.markdownguide.org/cheat-sheet/)

# %% [markdown]
# ### Listen und Aufzählungen
#
# * Liste
#   * eintrag 1
#   * eintrag 2

# %% [markdown]
# ToDo: Nummerierte Liste
# 1 Nummerierte List
# 1 eintrag
# 1 anderer Eintrag

# %% [markdown]
# ## Images
#
# ![image.png](attachment:image.png)
