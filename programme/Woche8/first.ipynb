# %% [markdown]
# # Einführung in die Python-Programmierung
#
# ## Variablen

# %% [markdown]
# * Einer Variablen in Python wird über ein Literal ein Wert zugewiesen

# %%
message = 'Hello'

# %% [markdown]
# * Ausgabe einer Variable durch die **BuildIn-Funktion** *print*

# %%
print(message)
# Out:
# Hello
